# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from potentials.synthetic.gaussian.block_diagonal import (
    BlockDiagonal0,
    BlockDiagonal1,
    BlockDiagonal2,
    BlockDiagonal3,
    BlockDiagonal4,
    BlockDiagonal5
)

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal0(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal1(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal2(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal3(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal4(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(BlockDiagonal5(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()
