# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from potentials.synthetic.multimodal import (
    DoubleGaussian0,
    TripleGaussian0,
    DoubleGaussian1,
    TripleGaussian1,
    TenRandomlyPositionedGaussians
)

# %%
torch.manual_seed(0)
x = pd.DataFrame(DoubleGaussian0(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(TripleGaussian0(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(DoubleGaussian1(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(TripleGaussian1(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()

# %%
torch.manual_seed(0)
x = pd.DataFrame(TenRandomlyPositionedGaussians(n_dim=100).sample((10000,))[:, :4])
sns.pairplot(x, corner=True)
plt.show()
